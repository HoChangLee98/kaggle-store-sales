# %%
import sys
sys.path.append("../src")

from validation import *

import matplotlib.pyplot as plt

# %%
validation = Validator(folder_path="../artifacts", model_name="lightgbm")
cv_result = validation.load_cv_result(version="iteration10000")

# %%
plt.figure(figsize=(12, 5))
plt.scatter(x=np.arange(len(cv_result["y_valid"])), y=cv_result["y_valid"], label="true", s=0.5)
plt.scatter(x=np.arange(len(cv_result["y_valid"])), y=cv_result["y_valid_pred"], label="pred", s=0.5)
plt.title(f"Cross Validation LightGBM Result")
plt.legend()
plt.show()

# %%
def check_cv_result(version:str, model_name:str):
    validation = Validator(folder_path="../artifacts", model_name=model_name)
    cv_result = validation.load_cv_result(version=version)
    plt.figure(figsize=(12, 5))
    plt.scatter(x=np.arange(len(cv_result["y_valid"])), y=cv_result["y_valid"], label="true", s=0.5)
    plt.scatter(x=np.arange(len(cv_result["y_valid"])), y=cv_result["y_valid_pred"], label="pred", s=0.5)
    plt.title(f"Cross Validation {version} Result")
    plt.legend()
    plt.show()

# %%
check_cv_result(version="baseline_0", model_name="catboost")
# Out:
# c:\Users\ghckd\anaconda3\envs\store-sales\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
check_cv_result(version="baseline_0", model_name="lightgbm")
